# %% [markdown]
# <a href="https://colab.research.google.com/github/AjayUnique/Customer-Segmentation/blob/main/Online_Retail_Customer_Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Title : Online Retail Customer Segmentation.**
#
# # **Problem Description**
#
# **In this project, your task is to identify major customer segments on a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail.The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers.**
#
# # **Data Description**
#
# **Attribute Information:**
#
#
# *   **InvoiceNo: Invoice number. Nominal, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation.**
#
# *   **StockCode: Product (item) code. Nominal, a 5-digit integral number uniquely assigned to each distinct product.**
#
# *   **Description: Product (item) name. Nominal.**
#
# *   **Quantity: The quantities of each product (item) per transaction. Numeric.**
#
#
# *   **InvoiceDate: Invice Date and time. Numeric, the day and time when each transaction was generated.**
#
# *   **UnitPrice: Unit price. Numeric, Product price per unit in sterling.**
# *   **CustomerID: Customer number. Nominal, a 5-digit integral number uniquely assigned to each customer.**
#
#
#
#
# *   **Country: Country name. Nominal, the name of the country where each customer resides.**

# %%
#importing libraries
import pandas  as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df=pd.read_csv("/content/gdrive/MyDrive/Capstone_Project_4/ Online Retail.csv")

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#     InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/10 8:26       2.55     17850.0  United Kingdom
# 1  12/1/10 8:26       3.39     17850.0  United Kingdom
# 2  12/1/10 8:26       2.75     17850.0  United Kingdom
# 3  12/1/10 8:26       3.39     17850.0  United Kingdom
# 4  12/1/10 8:26       3.39     17850.0  United Kingdom

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#           InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/11 12:50       0.85     12680.0  France
# 541905  12/9/11 12:50       2.10     12680.0  France
# 541906  12/9/11 12:50       4.15     12680.0  France
# 541907  12/9/11 12:50       4.15     12680.0  France
# 541908  12/9/11 12:50       4.95     12680.0  France

# %%
df.shape
# Out:
# (541909, 8)

# %% [markdown]
# # **Data Wrangling**

# %%
cust_coun=df[["Country","CustomerID"]].drop_duplicates()
cust_coun.groupby(['Country'])['CustomerID'].aggregate('count').reset_index().sort_values('CustomerID',ascending=False)
# Out:
#                  Country  CustomerID
# 36        United Kingdom        3950
# 14               Germany          95
# 13                France          87
# 31                 Spain          31
# 3                Belgium          25
# 33           Switzerland          21
# 27              Portugal          19
# 19                 Italy          15
# 12               Finland          12
# 1                Austria          11
# 25                Norway          10
# 24           Netherlands           9
# 0              Australia           9
# 6        Channel Islands           9
# 9                Denmark           9
# 7                 Cyprus           8
# 32                Sweden           8
# 20                 Japan           8
# 26                Poland           6
# 34                   USA           4
# 5                 Canada           4
# 37           Unspecified           4
# 18                Israel           4
# 15                Greece           4
# ...

# %%
#Keeping only United Kingdom data
df=df.query("Country=='United Kingdom'").reset_index(drop=True)

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     133600
# Country             0
# dtype: int64

# %%
#Removing missing values from CustomerID column
df=df[pd.notnull(df["CustomerID"])]

#Checking if there is any negative values in Quantity
df["Quantity"].min()
# Out:
# -80995

# %%
#Verifying if there are any -ve value in Unitprice
df["UnitPrice"].min()
# Out:
# 0.0

# %%
#Filtering out records with negative value
df=df[(df['Quantity']>0)]

# %%
#Converting the string date field to datetime
df['InvoiceDate']=pd.to_datetime(df['InvoiceDate'])

# %%
#Adding new column depicting total amount
df["TotalAmount"]=df["Quantity"]*df["UnitPrice"]

# %%
#After data cleaning checking data shape
df.shape
# Out:
# (354345, 9)

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalAmount
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom        15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom        22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34

# %% [markdown]
# # **EDA( Exploratory Data Analysis)**

# %%
top_10_customers=df['CustomerID'].value_counts().reset_index().rename(columns={'index':'CustomerID','CustomerID':'Products_purchasing_Count'}).head(10)
top_10_customers
# Out:
#    CustomerID  Products_purchasing_Count
# 0     17841.0                       7847
# 1     14096.0                       5111
# 2     12748.0                       4596
# 3     14606.0                       2700
# 4     15311.0                       2379
# 5     13089.0                       1818
# 6     13263.0                       1677
# 7     14298.0                       1637
# 8     15039.0                       1502
# 9     18118.0                       1279

# %%
# Top 10 frequent Customers
plt.figure(figsize=(18,6))
sns.barplot(x=top_10_customers['CustomerID'],y=top_10_customers['Products_purchasing_Count'].head(10))
plt.title('Top 10 frequent Customers.')
# Out:
# Text(0.5, 1.0, 'Top 10 frequent Customers.')

# %% [markdown]
# Customer ID- 17841 had purchased most number of products.

# %%
avg_amount=df.groupby('CustomerID')['TotalAmount'].mean().reset_index().rename(columns={'TotalAmount':'Avg_amount_per_customer'}).sort_values('Avg_amount_per_customer',ascending=False)

# %%
avg_amount
# Out:
#       CustomerID  Avg_amount_per_customer
# 0        12346.0             77183.600000
# 2599     16446.0             56157.500000
# 1608     15098.0             13305.500000
# 2095     15749.0              4453.430000
# 1683     15195.0              3861.000000
# ...          ...                      ...
# 327      13271.0                 2.264375
# 615      13684.0                 2.241000
# 3581     17816.0                 2.150588
# 1908     15503.0                 2.101286
# 314      13256.0                 0.000000
#
# [3921 rows x 2 columns]

# %%
# Average amount spent by each customer 
plt.figure(figsize=(12,6))
sns.barplot(x=avg_amount['CustomerID'].head(5),y=avg_amount['Avg_amount_per_customer'].head(15))
plt.title('Average amount spent by each Customer')
# Out:
# Text(0.5, 1.0, 'Average amount spent by each Customer')

# %% [markdown]
# $ 77183 is the highest amount spent by the CustomerID-16446

# %% [markdown]
# # **RFM Modelling**

# %%
#Recency=Latest date-Last Invoice date, frequency=count of total InvoiceID, 
#monetary=sum of total amount of each customer
import datetime as dt

#lastet date will be 2011-12-10 as last day in data is 2011-12-09.
Latest_Date=dt.datetime(2011,12,10)

# %%
RFMScores = df.groupby('CustomerID').agg({'InvoiceDate': lambda x: (Latest_Date - x.max()).days, 'InvoiceNo': lambda x: len(x), 'TotalAmount': lambda x: x.sum()})

#Converting Invoice Date into type int
RFMScores['InvoiceDate'] = RFMScores['InvoiceDate'].astype(int)

RFMScores.rename(columns={'InvoiceDate': 'Recency', 
                         'InvoiceNo': 'Frequency', 
                         'TotalAmount': 'Monetary'}, inplace=True)

RFMScores.reset_index().head(10)
# Out:
#    CustomerID  Recency  Frequency  Monetary
# 0     12346.0      325          1  77183.60
# 1     12747.0        2        103   4196.01
# 2     12748.0        0       4596  33719.73
# 3     12749.0        3        199   4090.88
# 4     12820.0        3         59    942.34
# 5     12821.0      214          6     92.72
# 6     12822.0       70         46    948.88
# 7     12823.0       74          5   1759.50
# 8     12824.0       59         25    397.12
# 9     12826.0        2         91   1474.72

# %%
#Descriptive statistics (Recency)
RFMScores.Recency.describe()
# Out:
# count    3921.000000
# mean       91.722265
# std        99.528532
# min         0.000000
# 25%        17.000000
# 50%        50.000000
# 75%       142.000000
# max       373.000000
# Name: Recency, dtype: float64

# %%
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')
x=RFMScores['Recency']
ax=sns.distplot(x)

# %%
#Descriptive statistics (Frequency)
RFMScores['Frequency'].describe()
# Out:
# count    3921.000000
# mean       90.371079
# std       217.796155
# min         1.000000
# 25%        17.000000
# 50%        41.000000
# 75%        99.000000
# max      7847.000000
# Name: Frequency, dtype: float64

# %%
x=RFMScores.query('Frequency<1000')['Frequency']
ax=sns.distplot(x)

# %%
#Descriptive statistics (Monetary)
RFMScores['Monetary'].describe()
# Out:
# count      3921.000000
# mean       1863.910113
# std        7481.922217
# min           0.000000
# 25%         300.040000
# 50%         651.820000
# 75%        1575.890000
# max      259657.300000
# Name: Monetary, dtype: float64

# %%
x=RFMScores.query('Monetary<10000')['Monetary']
ax=sns.distplot(x)

# %%
quantiles = RFMScores.quantile(q=[0.25,0.5,0.75])
quantiles = quantiles.to_dict()

# %%
#Functions to create R, F and M segments
# Arguments (x = value, p = recency, monetary_value, frequency, d = quartiles dict)

def RScoring(x,p,d):
    if x <= d[p][0.25]:
        return 1
    elif x <= d[p][0.50]:
        return 2
    elif x <= d[p][0.75]: 
        return 3
    else:
        return 4
    
def FnMScoring(x,p,d):
    if x <= d[p][0.25]:
        return 4
    elif x <= d[p][0.50]:
        return 3
    elif x <= d[p][0.75]: 
        return 2
    else:
        return 1

# %%
#Calculating by adding R, F and M segment value columns in the existing dataset to show R, F and M segment values
RFMScores['R'] = RFMScores['Recency'].apply(RScoring, args=('Recency',quantiles,))
RFMScores['F'] = RFMScores['Frequency'].apply(FnMScoring, args=('Frequency',quantiles,))
RFMScores['M'] = RFMScores['Monetary'].apply(FnMScoring, args=('Monetary',quantiles,))
RFMScores.head()
# Out:
#             Recency  Frequency  Monetary  R  F  M
# CustomerID
# 12346.0         325          1  77183.60  4  4  1
# 12747.0           2        103   4196.01  1  1  1
# 12748.0           0       4596  33719.73  1  1  1
# 12749.0           3        199   4090.88  1  1  1
# 12820.0           3         59    942.34  1  2  2

# %%
RFMScores['RFMGroup']=RFMScores['R'].map(str) + RFMScores['F'].map(str) + RFMScores['M'].map(str)
RFMScores.head()

RFMScores['RFMScore']=RFMScores[['R','F','M']].sum(axis=1)
RFMScores.head()
# Out:
#             Recency  Frequency  Monetary  R  F  M RFMGroup  RFMScore
# CustomerID
# 12346.0         325          1  77183.60  4  4  1      441         9
# 12747.0           2        103   4196.01  1  1  1      111         3
# 12748.0           0       4596  33719.73  1  1  1      111         3
# 12749.0           3        199   4090.88  1  1  1      111         3
# 12820.0           3         59    942.34  1  2  2      122         5

# %%
#Assigning Loyalty Level to each customer
Loyalty_Level = ['Platinum', 'Gold', 'Silver','Bronze']
Score_cuts = pd.qcut(RFMScores.RFMScore, q = 4, labels = Loyalty_Level)
RFMScores['RFM_Loyalty_Level'] = Score_cuts.values
RFMScores.reset_index().head()
# Out:
#    CustomerID  Recency  Frequency  Monetary  R  F  M RFMGroup  RFMScore  \
# 0     12346.0      325          1  77183.60  4  4  1      441         9
# 1     12747.0        2        103   4196.01  1  1  1      111         3
# 2     12748.0        0       4596  33719.73  1  1  1      111         3
# 3     12749.0        3        199   4090.88  1  1  1      111         3
# 4     12820.0        3         59    942.34  1  2  2      122         5
#
#   RFM_Loyalty_Level
# 0            Silver
# 1          Platinum
# 2          Platinum
# 3          Platinum
# 4          Platinum

# %%
#Validating the data for RFMGroup = 111
RFMScores[RFMScores['RFMGroup']=='111'].sort_values('Monetary', ascending=False).reset_index().head(10)
# Out:
#    CustomerID  Recency  Frequency   Monetary  R  F  M RFMGroup  RFMScore  \
# 0     18102.0        0        431  259657.30  1  1  1      111         3
# 1     17450.0        8        337  194550.79  1  1  1      111         3
# 2     17511.0        2        963   91062.38  1  1  1      111         3
# 3     16684.0        4        277   66653.56  1  1  1      111         3
# 4     14096.0        4       5111   65164.79  1  1  1      111         3
# 5     13694.0        3        568   65039.62  1  1  1      111         3
# 6     15311.0        0       2379   60767.90  1  1  1      111         3
# 7     13089.0        2       1818   58825.83  1  1  1      111         3
# 8     15769.0        7        130   56252.72  1  1  1      111         3
# 9     15061.0        3        403   54534.14  1  1  1      111         3
#
#   RFM_Loyalty_Level
# 0          Platinum
# 1          Platinum
# 2          Platinum
# 3          Platinum
# 4          Platinum
# 5          Platinum
# ...

# %% [markdown]
# **In this project, we have selected 1 as the best RFM value and 4 as the worst.So the best RFMScore is '111'and worst is '444'. We can do vice-versa aslo.**

# %% [markdown]
# **Here on the basis of RFMScore we have created 4 groups/loyalty level because we have used 4 quantile here.**

# %%
#Handling negative and zero values so as to handle infinite numbers during log transformation
def handle_neg_n_zero(num):
    if num <= 0:
        return 1
    else:
        return num
#Applying handle_neg_n_zero function to Recency and Monetary columns 
RFMScores['Recency'] = [handle_neg_n_zero(x) for x in RFMScores.Recency]
RFMScores['Monetary'] = [handle_neg_n_zero(x) for x in RFMScores.Monetary]

#Performing Log transformation to bring data into normal or near normal distribution
Log_Tfd_Data = RFMScores[['Recency', 'Frequency', 'Monetary']].apply(np.log, axis = 1).round(3)

# %%
Recency_Plot = Log_Tfd_Data['Recency']
ax = sns.distplot(Recency_Plot)

# %%
Frequency_Plot = Log_Tfd_Data.query('Frequency < 1000')['Frequency']
ax = sns.distplot(Frequency_Plot)

# %%
Monetary_Plot = Log_Tfd_Data.query('Monetary < 10000')['Monetary']
ax = sns.distplot(Monetary_Plot)

# %%
from sklearn.preprocessing import StandardScaler

#Bringing the data on same scale
scaleobj = StandardScaler()
Scaled_Data = scaleobj.fit_transform(Log_Tfd_Data)

#Transforming it back to dataframe
Scaled_Data = pd.DataFrame(Scaled_Data, index = RFMScores.index, columns = Log_Tfd_Data.columns)

# %% [markdown]
# # **K Means Clustering**

# %%
from sklearn.cluster import KMeans

sum_of_sq_dist = {}
for k in range(1,15):
    km = KMeans(n_clusters= k, init= 'k-means++', max_iter= 1000)
    km = km.fit(Scaled_Data)
    sum_of_sq_dist[k] = km.inertia_
    
#Plotting the graph for the sum of square distance values and Number of Clusters
sns.pointplot(x = list(sum_of_sq_dist.keys()), y = list(sum_of_sq_dist.values()))
plt.xlabel('Number of Clusters(k)')
plt.ylabel('Sum of Square Distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
# silhouette analysis
range_n_clusters = [2, 3, 4, 5, 6, 7, 8]

for num_clusters in range_n_clusters:
    
    # intialise kmeans
    kmeans = KMeans(n_clusters=num_clusters, max_iter=50)
    kmeans.fit(Scaled_Data)
    
    cluster_labels = kmeans.labels_
    
    # silhouette score
    silhouette_avg = silhouette_score(Scaled_Data, cluster_labels)
    print("For n_clusters={0}, the silhouette score is {1}".format(num_clusters, silhouette_avg))
# Out:
# For n_clusters=2, the silhouette score is 0.39562494982602087
# For n_clusters=3, the silhouette score is 0.3067620960511527
# For n_clusters=4, the silhouette score is 0.29815523287072787
# For n_clusters=5, the silhouette score is 0.27985615254719015
# For n_clusters=6, the silhouette score is 0.2772539944580759
# For n_clusters=7, the silhouette score is 0.2604500522408887
# For n_clusters=8, the silhouette score is 0.26104942165941986

# %%
#Performing K-Mean Clustering or build the K-Means clustering model
KMean_clust = KMeans(n_clusters= 3, init= 'k-means++', max_iter= 1000)
KMean_clust.fit(Scaled_Data)

RFMScores['Cluster'] = KMean_clust.labels_
RFMScores.head()
# Out:
#             Recency  Frequency  Monetary  R  F  M RFMGroup  RFMScore  \
# CustomerID
# 12346.0         325          1  77183.60  4  4  1      441         9
# 12747.0           2        103   4196.01  1  1  1      111         3
# 12748.0           1       4596  33719.73  1  1  1      111         3
# 12749.0           3        199   4090.88  1  1  1      111         3
# 12820.0           3         59    942.34  1  2  2      122         5
#
#            RFM_Loyalty_Level  Cluster
# CustomerID
# 12346.0               Silver        2
# 12747.0             Platinum        0
# 12748.0             Platinum        0
# 12749.0             Platinum        0
# 12820.0             Platinum        0

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(7,7))

##Scatter Plot Frequency Vs Recency
Colors = ["red", "green", "blue"]
RFMScores['Color'] = RFMScores['Cluster'].map(lambda p: Colors[p])
ax = RFMScores.plot(    
    kind="scatter", 
    x="Recency", y="Frequency",
    figsize=(10,8),
    c = RFMScores['Color']
)

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# *   There were 4 groups formed in the RFM method.
# *   With the help of elbow method and silhouette mrthod,the best value for k is 3. So there are 3 clusters in K-Means Clustering Method.
# *   The cluster having color red are the Best customers with the low RFM Score.
